# %%
age = int(input("Enter your age: "))
if age >= 18 :
    print("You are old enough to drive")
else:
    print(f"You need {18 - age} more years to learn to drive")
# Out:
# You need 3 more years to learn to drive

# %%
y_age = int(input("Enter your age: "))
m_age = 21
if y_age == m_age:
    print("my_age = your_age")
elif y_age - m_age == 1:
    print("Your are 1 year older than me")
else:
    print(f"You are {y_age - m_age} years older than me")
# Out:
# You are 9 years older than me

# %%
month = input("Enter a month: ").strip().capitalize()

if month in ["September", "October", "November"]:
    print("The season is Autumn.")
elif month in ["December", "January", "February"]:
    print("The season is Winter.")
elif month in ["March", "April", "May"]:
    print("The season is Spring.")
elif month in ["June", "July", "August"]:
    print("The season is Summer.")
# Out:
# The season is Summer.
